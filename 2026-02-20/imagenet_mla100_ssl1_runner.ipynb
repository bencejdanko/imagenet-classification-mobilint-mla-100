# %% [markdown]
# # SETUP

# %%
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/bencejdanko/imagenet-classification-mobilint-mla-100

# ensure latest
os.chdir('/content/imagenet-classification-mobilint-mla-100')
# !cd /content/imagenet-classification-mobilint-mla-100 && git pull
# Out:
# Cloning into 'imagenet-classification-mobilint-mla-100'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 79 (delta 31), reused 64 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 16.79 MiB | 21.23 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 406 bytes | 406.00 KiB/s, done.
# From https://github.com/bencejdanko/imagenet-classification-mobilint-mla-100
#    ba60a70..ebd0bb7  main       -> origin/main
# Updating ba60a70..ebd0bb7
# Fast-forward
#  2026-02-20/imagenet_mla100_ssl2/train.py | 9 ++-------
#  1 file changed, 2 insertions(+), 7 deletions(-)

# %%
# copy over package
# !cp -r /content/imagenet-classification-mobilint-mla-100/2026-02-20/imagenet_mla100_ssl2 imagenet_mla100_ssl2

# %%
import sys
sys.path.append('/content/imagenet_mla100_ssl2')

# %%
# !pip -q install onnxscript onnxruntime
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 106.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.3/159.3 kB 18.8 MB/s eta 0:00:00

# %% [markdown]
# # IMPLEMENTATION

# %%
# download all necessary data
import download

# %%
import train
# Out:
# Epoch [1] Step [10/188] | Acc: 7.19% | Cls Loss: 2.9974 | Recon Loss: 0.0940
# Epoch [1] Step [20/188] | Acc: 6.41% | Cls Loss: 2.9954 | Recon Loss: 0.0930
# Epoch [1] Step [30/188] | Acc: 6.25% | Cls Loss: 2.9986 | Recon Loss: 0.0921
# Epoch [1] Step [40/188] | Acc: 5.86% | Cls Loss: 2.9935 | Recon Loss: 0.0912
# Epoch [1] Step [50/188] | Acc: 5.62% | Cls Loss: 2.9962 | Recon Loss: 0.0903
# Epoch [1] Step [60/188] | Acc: 5.73% | Cls Loss: 2.9921 | Recon Loss: 0.0894
# Epoch [1] Step [70/188] | Acc: 5.49% | Cls Loss: 2.9973 | Recon Loss: 0.0885
# Epoch [1] Step [80/188] | Acc: 5.47% | Cls Loss: 3.0025 | Recon Loss: 0.0876
# Epoch [1] Step [90/188] | Acc: 5.24% | Cls Loss: 2.9926 | Recon Loss: 0.0868
# Epoch [1] Step [100/188] | Acc: 5.03% | Cls Loss: 2.9941 | Recon Loss: 0.0859
# Epoch [1] Step [110/188] | Acc: 4.94% | Cls Loss: 2.9952 | Recon Loss: 0.0851
# Epoch [1] Step [120/188] | Acc: 4.79% | Cls Loss: 2.9951 | Recon Loss: 0.0842
# Epoch [1] Step [130/188] | Acc: 4.90% | Cls Loss: 3.0011 | Recon Loss: 0.0834
# Epoch [1] Step [140/188] | Acc: 5.04% | Cls Loss: 2.9949 | Recon Loss: 0.0826
# Epoch [1] Step [150/188] | Acc: 4.92% | Cls Loss: 2.9965 | Recon Loss: 0.0818
# Epoch [1] Step [160/188] | Acc: 4.88% | Cls Loss: 2.9960 | Recon Loss: 0.0810
# Epoch [1] Step [170/188] | Acc: 4.85% | Cls Loss: 2.9986 | Recon Loss: 0.0802
# Epoch [1] Step [180/188] | Acc: 4.72% | Cls Loss: 3.0023 | Recon Loss: 0.0795
# >> Epoch 1 Summary: Val Acc: 5.00% <<
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3668338572.py in <cell line: 0>()
# ----> 1 import train
#
# /content/imagenet_mla100_ssl2/train.py in <module>
#      89
#      90     # 1. Fix the Unpacking (Now expects 3 items from the masked dataloader)
# ---> 91     for i, (masked_images, target_images, labels) in enumerate(train_loader):
#      92         masked_images = masked_images.to(device)
#      93         target_images = target_images.to(device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     799     def _next_data(self):
#     800         index = self._next_index()  # may raise StopIteration
# --> 801         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802         if self._pin_memory:
#     803             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52                 data = self.dataset.__getitems__(possibly_batched_index)
#      53             else:
# ---> 54                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      55         else:
#      56             data = self.dataset[possibly_batched_index]
#
# /content/imagenet_mla100_ssl2/dataloader.py in __getitem__(self, idx)
#      55
#      56         # 1. Apply standard augmentations (Resize, ColorJitter, ToTensor)
# ---> 57         target_image = self.transform(image) if self.transform else image
#      58
#      59         # 2. Generate the masked version for the input
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/transforms.py in forward(self, img)
#    1282                 img = F.adjust_brightness(img, brightness_factor)
#    1283             elif fn_id == 1 and contrast_factor is not None:
# -> 1284                 img = F.adjust_contrast(img, contrast_factor)
#    1285             elif fn_id == 2 and saturation_factor is not None:
#    1286                 img = F.adjust_saturation(img, saturation_factor)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/functional.py in adjust_contrast(img, contrast_factor)
#     905         _log_api_usage_once(adjust_contrast)
#     906     if not isinstance(img, torch.Tensor):
# --> 907         return F_pil.adjust_contrast(img, contrast_factor)
#     908
#     909     return F_t.adjust_contrast(img, contrast_factor)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/_functional_pil.py in adjust_contrast(img, contrast_factor)
#      83         raise TypeError(f"img should be PIL Image. Got {type(img)}")
#      84
# ---> 85     enhancer = ImageEnhance.Contrast(img)
#      86     img = enhancer.enhance(contrast_factor)
#      87     return img
#
# /usr/local/lib/python3.12/dist-packages/PIL/ImageEnhance.py in __init__(self, image)
#      73         if image.mode != "L":
#      74             image = image.convert("L")
# ---> 75         mean = int(ImageStat.Stat(image).mean[0] + 0.5)
#      76         self.degenerate = Image.new("L", image.size, mean)
#      77         if self.degenerate.mode != self.image.mode:
#
# /usr/local/lib/python3.12/dist-packages/PIL/ImageStat.py in __init__(self, image_or_list, mask)
#      52         """
#      53         if isinstance(image_or_list, Image.Image):
# ---> 54             self.h = image_or_list.histogram(mask)
#      55         elif isinstance(image_or_list, list):
#      56             self.h = image_or_list
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in histogram(self, mask, extrema)
#    1701                 extrema if extrema is not None else self.getextrema()
#    1702             )
# -> 1703         return self.im.histogram()
#    1704
#    1705     def entropy(
#
# KeyboardInterrupt:
